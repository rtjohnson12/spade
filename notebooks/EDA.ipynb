# %%
import pandas as pd
import dbfread as db

# %%
table = db.DBF('data-raw/Set1/set1data.dbf', load=True)

# %%
table.records
# Out:
#   ('PatchID', 77.0),
#               ('HtClID', 536.0),
#               ('HtClArea', 3100.7),
#               ('HtClass', 'm'),
#               ('CoverClass', 'd'),
#               ('PatchWidth', 180.0)]),
#  OrderedDict([('SP_ID', '956'),
#               ('ID', 1676.0),
#               ('AgeID', 355.0),
#               ('AgeArea', 74112.5507977),
#               ('Age', 19.0),
#               ('VegType', 'v'),
#               ('PatchArea', 157800.671875),
#               ('PatchID', 77.0),
#               ('HtClID', 548.0),
#               ('HtClArea', 1724.61),
#               ('HtClass', 'l'),
#               ('CoverClass', 'm'),
#               ('PatchWidth', 180.0)]),
#  OrderedDict([('SP_ID', '957'),
#               ('ID', 1677.0),
#               ('AgeID', 355.0),
#               ('AgeArea', 74112.5507977),
#               ('Age', 19.0),
#               ('VegType', 'v'),
#               ('PatchArea', 157800.671875),
#               ('PatchID', 77.0),
# ...
