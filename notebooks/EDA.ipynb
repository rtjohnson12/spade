# %% [markdown]
# # Exploratory Data Analysis
#
# ### Set-Up

# %%
import pandas as pd
import dbfread as db
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

df = pd.read_csv('../data-raw/Set4/Set4.196sample.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         86 non-null     int64
#  1   Row        86 non-null     int64
#  2   Column     86 non-null     int64
#  3   Easting    86 non-null     float64
#  4   Northing   86 non-null     float64
#  5   RowCol     86 non-null     object
#  6   Sand       86 non-null     float64
#  7   Silt       86 non-null     float64
#  8   Clay       86 non-null     float64
#  9   SoilpH     86 non-null     float64
#  10  SoilTOC    86 non-null     float64
#  11  SoilTN     86 non-null     float64
#  12  SoilP      86 non-null     float64
#  13  SoilK      86 non-null     float64
#  14  CropDens   86 non-null     int64
#  15  Weeds      86 non-null     int64
#  16  Disease    86 non-null     int64
#  17  SPAD       86 non-null     float64
#  18  GrainProt  86 non-null     float64
# ...

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df['Northing'], df['Easting'], df['Sand'], 'gray')

# %%
ax = plt.axes(projection='3d')
ax.plot_trisurf(df['Northing'], df['Easting'], df['Sand'],
                cmap = 'viridis', edgecolor='none');

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d7/vzxy3qb52r312170_4tkrrd00000gn/T/ipykernel_52725/4229943342.py in <module>
#       1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
# ----> 3 ax.contour3D(X, Y, Z, 50, cmap='binary')
#       4 ax.set_xlabel('x')
#       5 ax.set_ylabel('y')
#
# ~/Documents/Projects/spade/.venv/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in contour(self, X, Y, Z, extend3d, stride, zdir, offset, *args, **kwargs)
#    2173
#    2174         jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
# -> 2175         cset = super().contour(jX, jY, jZ, *args, **kwargs)
#    2176         self.add_contour_set(cset, extend3d, stride, zdir, offset)
#    2177
#
# ~/Documents/Projects/spade/.venv/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# ### Set 1

# %%
table = db.DBF('data-raw/Set1/set1data.dbf', load=True)

# %%
table.records
# Out:
#   ('PatchID', 77.0),
#               ('HtClID', 536.0),
#               ('HtClArea', 3100.7),
#               ('HtClass', 'm'),
#               ('CoverClass', 'd'),
#               ('PatchWidth', 180.0)]),
#  OrderedDict([('SP_ID', '956'),
#               ('ID', 1676.0),
#               ('AgeID', 355.0),
#               ('AgeArea', 74112.5507977),
#               ('Age', 19.0),
#               ('VegType', 'v'),
#               ('PatchArea', 157800.671875),
#               ('PatchID', 77.0),
#               ('HtClID', 548.0),
#               ('HtClArea', 1724.61),
#               ('HtClass', 'l'),
#               ('CoverClass', 'm'),
#               ('PatchWidth', 180.0)]),
#  OrderedDict([('SP_ID', '957'),
#               ('ID', 1677.0),
#               ('AgeID', 355.0),
#               ('AgeArea', 74112.5507977),
#               ('Age', 19.0),
#               ('VegType', 'v'),
#               ('PatchArea', 157800.671875),
#               ('PatchID', 77.0),
# ...
